# %% [markdown]
# # Pipeline for the anomaly detection on the SKAB using LSTM-based NN

# %% [markdown]
# Details regarding the SKAB one can find in the [SKAB repository](https://github.com/waico/SKAB).

# %%
# libraries importing
import sys
import warnings

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

sys.path.append("..")
from core.Vanilla_LSTM_pytorch import Vanilla_LSTM
from core.metrics import chp_score
from core.utils import load_preprocess_skab, plot_results

warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Data

# %%
Xy_traintest_list = load_preprocess_skab()

# %% [markdown]
# ## Method

# %% [markdown]
# ### Method initialization

# %%
# hyperparameters selection
N_STEPS = 5
EPOCHS = 40
BATCH_SIZE = 32
VAL_SPLIT = 0.2
PARAMS = [N_STEPS, EPOCHS, BATCH_SIZE, VAL_SPLIT]
Q = 0.99  # quantile for upper control limit (UCL) selection

# %%
# model defining
model = Vanilla_LSTM(PARAMS)

# %%
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences) - 1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %% [markdown]
# ### Method fitting and applying

# %%
# inference
predicted_outlier, predicted_cp = [], []
true_outlier, true_cp = [], []
all_scores = []
for X_train, X_test, y_train, y_test in Xy_traintest_list:
    # scaler init and fitting
    StSc = StandardScaler()
    StSc.fit(X_train)

    # convert into input/output
    X, y = split_sequences(StSc.transform(X_train), N_STEPS)

    # model fitting
    model.fit(X, y)

    # results predicting
    residuals_train = pd.DataFrame(y - model.predict(X)).abs().sum(axis=1)
    UCL = residuals_train.quantile(Q) * 5

    # results predicting
    X, y = split_sequences(StSc.transform(X_test), N_STEPS)
    lstm_residuals = pd.DataFrame(y - model.predict(X)).abs().sum(axis=1)
    all_scores.append(lstm_residuals)
    prediction = pd.Series(
        (lstm_residuals > UCL).astype(int).values, index=X_test[N_STEPS:].index
    ).fillna(0)

    # predicted outliers saving
    predicted_outlier.append(prediction)

    # predicted CPs saving
    prediction_cp = abs(prediction.diff())
    prediction_cp.iloc[0] = prediction.iloc[0]
    predicted_cp.append(prediction_cp)

    true_outlier.append(
    y_test["anomaly"].iloc[N_STEPS:]
    )
    
    true_cp.append(
        y_test["changepoint"].iloc[N_STEPS:]
    )

# %% [markdown]
# ### Results visualization

# %%
# --- FINAL FIX: bezpieczne przygotowanie danych do wykresu ---

true_o = true_outlier[1].rename("Outlier")

pred_o = (
    predicted_outlier[1]
    .apply(lambda x: x.values[0] if hasattr(x, "values") else x)
    .fillna(0)
    .astype(int)
)

true_c = true_cp[1].rename("Changepoint")

pred_c = (
    predicted_cp[1]
    .apply(lambda x: x.values[0] if hasattr(x, "values") else x)
    .fillna(0)
    .astype(int)
)

plot_results(
    (true_o, pred_o),
    (true_c, pred_c),
)

# %% [markdown]
# ## Evaluation (metrics calculation)

# %%
import pickle

pickle.dump(
    predicted_outlier,
    open(f"../results/results-{model.__class__.__name__}.pkl", "wb"),
)

# %%
from core.plot_learning_curve import plot_learning_curve

# %%
plot_learning_curve(
    model,
    'Vanilla LSTM',
    save_path='images/lc_vanilla_lstm.png'
)
# Out:
# Zapisano: images/lc_vanilla_lstm.png

# %%
import os

# %%
os.makedirs("images", exist_ok=True)

plot_learning_curve(
    model,
    'Vanilla LSTM',
    save_path='images/lc_vanilla_lstm.png'
)
# Out:
# Zapisano: images/lc_vanilla_lstm.png

# %%
print(len(all_scores))
print(len(true_outlier))

print(len(all_scores[0]))
print(len(true_outlier[0]))
# Out:
# 34
# 34
# 340
# 340

# %%
from core.plot_roc_pr import plot_roc_pr

metrics_lstm = plot_roc_pr(
    scores_list=all_scores,
    labels_list=true_outlier,
    model_name='Vanilla LSTM',
    save_roc='images/roc_vanilla_lstm.png',
    save_pr='images/pr_vanilla_lstm.png',
)

print(metrics_lstm)
# Out:
# Zapisano ROC: images/roc_vanilla_lstm.png
# Zapisano PR: images/pr_vanilla_lstm.png
# ==================================================
# Model:    Vanilla LSTM
# AUC-ROC:  0.7891
# PR-AUC:   0.8206
# MCC:      0.4510  (próg optymalny = 9.4677)
# ==================================================
#
# {'auc_roc': 0.7891, 'pr_auc': 0.8206, 'mcc': 0.451}

# %%
from pathlib import Path
import numpy as np

Path('results').mkdir(exist_ok=True)

np.save(
    'results/scores_vanilla_lstm.npy',
    np.array(all_scores, dtype=object),
    allow_pickle=True
)

np.save(
    'results/labels_vanilla_lstm.npy',
    np.array(true_outlier, dtype=object),
    allow_pickle=True
)

print("OK: Vanilla LSTM zapisany")
# Out:
# OK: Vanilla LSTM zapisany

# %% [markdown]
# ### Binary classification (outlier detection) metrics

# %%
# [donotremove]
# binary classification metrics calculation
binary = chp_score(true_outlier, predicted_outlier, metric="binary")
# Out:
# False Alarm Rate 0.32 %
# Missing Alarm Rate 84.02 %
# F1 metric 0.27

# %% [markdown]
# ### Changepoint detection metrics

# %%
# [donotremove]
# average detection delay metric calculation
add = chp_score(
    true_cp,
    predicted_cp,
    metric="average_time",
    window_width="60s",
    anomaly_window_destination="righter",
)
# Out:
# Amount of true anomalies 127
# A number of missed CPs = 115
# A number of FPs = 3
# Average time 0 days 00:00:18.166666

# %%
# [donotremove]
# nab metric calculation
nab = chp_score(
    true_cp,
    predicted_cp,
    metric="nab",
    window_width="60s",
    anomaly_window_destination="righter",
)
# Out:
# Standard  -  7.83
# LowFP  -  7.55
# LowFN  -  8.37
