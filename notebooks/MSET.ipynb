# %% [markdown]
# # Pipeline for the anomaly detection on the SKAB using MSET

# %% [markdown]
# Details regarding the SKAB one can find in the [SKAB repository](https://github.com/waico/SKAB).

# %% [markdown]
# ## Libraries importing

# %%
# libraries importing
import math
import sys
import warnings

import numpy as np
import pandas as pd

sys.path.append("..")
from core.MSET import MSET
from core.metrics import chp_score
from core.utils import load_preprocess_skab, plot_results

warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Data

# %%
Xy_traintest_list = load_preprocess_skab()

# %% [markdown]
# ## Method

# %% [markdown]
# ### Method initialization

# %%
def movmean(array, window):
    n = np.size(array)
    xx = array.copy()
    y = []
    for i in range(0, window):
        y.append(np.roll(xx.tolist() + [np.nan] * window, i))
    y = np.nanmean(y, axis=0)
    window_ceil = math.ceil(window / 2)

    return y[window_ceil - 1 : n + window_ceil - 1]

# %% [markdown]
# ### Method fitting and applying

# %%
# inference
predicted_outlier, predicted_cp = [], []
true_outlier, true_cp = [], []
rel_errors = []
all_scores = []
x = 0
for X_train, X_test, y_train, y_test in Xy_traintest_list:
    x += 1

    model = MSET()
    model.fit(X_train)

    # results predicting
    Y_pred = model.predict(X_test)
    err = np.linalg.norm(X_test - Y_pred, axis=1)
    rel_err = movmean(err / np.linalg.norm(Y_pred, axis=1), window=60)
    rel_errors.append(rel_err)
    all_scores.append(pd.Series(rel_err, index=X_test.index))

    UCL = 0.01
    prediction = (
        pd.DataFrame((rel_err > UCL), X_test.index)
        .fillna(0)
        .any(axis=1)
        .astype(int)
    )

    # predicted outliers saving
    predicted_outlier.append(prediction)

    # predicted CPs saving
    prediction_cp = abs(prediction.diff())
    prediction_cp.iloc[0] = prediction.iloc[0]
    predicted_cp.append(prediction_cp)

    true_outlier.append(y_test["anomaly"])
    true_cp.append(y_test["changepoint"])
# Out:
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)
# C:\Users\olegs\AppData\Local\Temp\ipykernel_23952\237449712.py:7: RuntimeWarning: Mean of empty slice
#   y = np.nanmean(y, axis=0)

# %% [markdown]
# ### Results visualization

# %%
# [donotremove]
plot_results(
    (true_outlier[1], predicted_outlier[1]),
    (true_cp[1], predicted_cp[1]),
)

# %%
import os
from core.plot_roc_pr import plot_roc_pr

os.makedirs("images", exist_ok=True)

metrics_mset = plot_roc_pr(
    scores_list=all_scores,
    labels_list=true_outlier,
    model_name='MSET',
    save_roc='images/roc_mset.png',
    save_pr='images/pr_mset.png',
)
print(metrics_mset)
# Out:
# Zapisano ROC: images/roc_mset.png
# Zapisano PR: images/pr_mset.png
# ==================================================
# Model:    MSET
# AUC-ROC:  0.8174
# PR-AUC:   0.8260
# MCC:      0.4855  (próg optymalny = 0.0115)
# ==================================================
#
# {'auc_roc': 0.8174, 'pr_auc': 0.826, 'mcc': 0.4855}

# %%
from pathlib import Path
import numpy as np

Path('results').mkdir(exist_ok=True)

np.save(
    'results/scores_mset.npy',
    np.array(all_scores, dtype=object),
    allow_pickle=True
)

np.save(
    'results/labels_mset.npy',
    np.array(true_outlier, dtype=object),
    allow_pickle=True
)

print("OK: MSET zapisany")
# Out:
# OK: MSET zapisany

# %% [markdown]
# ## Evaluation (metrics calculation)

# %%
import pickle

pickle.dump(
    predicted_outlier,
    open(f"../results/results-{model.__class__.__name__}.pkl", "wb"),
)

# %% [markdown]
# ### Binary classification (outlier detection) metrics

# %%
# [donotremove]
# binary classification metrics calculation
binary = chp_score(true_outlier, predicted_outlier, metric="binary")
# Out:
# False Alarm Rate 39.73 %
# Missing Alarm Rate 14.13 %
# F1 metric 0.78

# %% [markdown]
# ### Changepoint detection metrics

# %%
# [donotremove]
# average detection delay metric calculation
add = chp_score(
    true_cp,
    predicted_cp,
    metric="average_time",
    window_width="60s",
    anomaly_window_destination="righter",
)
# Out:
# Amount of true anomalies 127
# A number of missed CPs = 96
# A number of FPs = 66
# Average time 0 days 00:00:33.419354

# %%
# [donotremove]
# nab metric calculation
nab = chp_score(
    true_cp,
    predicted_cp,
    metric="nab",
    window_width="60s",
    anomaly_window_destination="righter",
)
# Out:
# Standard  -  13.84
# LowFP  -  10.22
# LowFN  -  17.37
